# %%
import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

logo = ''' 
 _                                             
| |                                            
| |__   __ _ _ __   __ _ _ __ ___   __ _ _ __  
| '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \ 
| | | | (_| | | | | (_| | | | | | | (_| | | | |
|_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
                    __/ |                      
                   |___/    '''

word_list = ["python", "telegram", "azure", "software", "boxcar"]

word_generator = random.choice(word_list) #generate random word from the list

letter_list = [] #saves the generated word into list
for let in word_generator: 
    letter_list += let
print(letter_list)

display_blanks = [] #create '_' to the length of word
for blanks in range(len(letter_list)):
    display_blanks += "_"
    
clear()
user_failedtries = 0
while "_" in display_blanks:
    user_guess = input("Guess the letter: ").lower()
    for position in range(len(letter_list)): #position var will store the position of letter
        letter_position = letter_list[position] #letter_pos will store the letter
        if letter_position == user_guess:
            display_blanks[position] = user_guess
            print(display_blanks)
    if user_guess not in letter_list:
        user_failedtries += 1
        if user_failedtries == 8:
            print("You died!")
            print(letter_list)
            break
        else:
            print(stages[user_failedtries - 1])
    if "_" not in display_blanks:
        print("You won!")
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']
# Guess the letter: p
# ['p', '_', '_', '_', '_', '_']
# Guess the letter: y
# ['p', 'y', '_', '_', '_', '_']
# Guess the letter: t
# ['p', 'y', 't', '_', '_', '_']
# Guess the letter: h
# ['p', 'y', 't', 'h', '_', '_']
# Guess the letter: o
# ['p', 'y', 't', 'h', 'o', '_']
# Guess the letter: n
# ['p', 'y', 't', 'h', 'o', 'n']
# You won!
